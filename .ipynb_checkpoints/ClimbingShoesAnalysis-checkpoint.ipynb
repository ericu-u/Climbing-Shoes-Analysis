# %% [markdown]
# # Climbing Shoes Analysis Project
#
# The primary goal of this project is to determine the most cost-efficient climbing shoes for an intermediate climber. My motivation for this project comes from both my love for climbing and my need for new climbing shoes. Shoes are such an important and powerful aspect of climbing, that they often make or break climbing attempts. I often joke that anytime I fail a climb, it's a problem with the shoes.
#
# My projection for this project involves web-scraping information from the men's climbing shoes section from the REI (Recreational Equipment Inc.) website. Information I want to get include the shoe name, shoe brand, price, discount status, and ratings. Once I get this information, I want to utilize an SQL database to store the data and potentially create a prediction model that scores the shoes. Lastly, I want to summarize my findings in clean visualizations through Tableau and/or Python.
#
# Let's get started! First things first, let's import some python packages import for web-scraping as well as SQL connecting.

# %%
# Import necessary packages for webscraping and data collection
import bs4
import requests
from bs4 import BeautifulSoup
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
from splinter.browser import Browser
import numpy as np

# Load SQL extension
# %load_ext sql

# Matplot frontend
# %matplotlib inline
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ### Step One: Webscraping
#
# I originally only wanted to use the requests and Beautiful Soup packages to webscrape the REI site, but the products' ratings were dynamic html content, which Beautiful Soup can't access. Thus, I delved into the splinter package specifically for the ratings. This wasn't really what I wanted because I'm unfamiliar with this process and also I needed to download chromedriver.exe which opens a new browser while running the program. In addition, having this additional software means that I need to eventually update these extra parts when Chrome or chromedriver updates rollout.

# %%
def scrape_rei(link):
    temp_df = pd.DataFrame(columns = ['Shoe_Name', 'Shoe_Company', 'Current_Price', 'Original_Price', 'Discount', 'Product_Link'])
    
    # Splinter browser opens new chrome browser window
    br = Browser('chrome')
    br.visit(link)

    # Make a request to the primary url and uses an html parser to gather data
    req = requests.get(link)
    soup = bs4.BeautifulSoup(req.text, 'html.parser')

    # Use find all to get a list of each product's html information
    page_lst = soup.find_all('li', {'class': 'pPe0GNuagvmEFURs1Q_vm'})

    # Create a for loop that runs through each product and uses the find function
    # to aquire specific data observations
    for element in page_lst:
        shoe_name = element.find('div', {'class': 'r9nAQ5Ik_3veCKyyZkP0b'}).text
        if shoe_name[-8:] == " - Men's":
            shoe_name = shoe_name[:-8]

        shoe_company = element.find('div', {'class': '_1fwp3k8dh1lbhAAenp87CH'}).text

        if element.find('span', {'class': '_2xZVXKL4Bd0pJyQCumYi9P'}) != None:
            current_price = element.find('span', {'class': '_2xZVXKL4Bd0pJyQCumYi9P'}).text
            original_price = element.find('span', {'class': 'Dm_X3ktyv_w_gPWuYlJf_'}).text
            original_price = original_price[11:]
        else:
            current_price = element.find('div', {'class': '_1zwqhlCzOK-xETXwFg_-iZ'}).text
            original_price = element.find('div', {'class': '_1zwqhlCzOK-xETXwFg_-iZ'}).text

        if current_price != original_price:
            on_sale = True
        else:
            on_sale = False
            
        product_link = element.find('a')['href']

        # Append each row to the shoes dataframe
        temp_row = [shoe_name, shoe_company, current_price, original_price, on_sale, 'https://www.rei.com' + product_link]
        temp_df.loc[len(temp_df)] = temp_row
        
    # Use the splinter browser to gather dynamic html data of ratings
    # Also clean the data as we scrape it
    ratings = []
    for item in br.find_by_tag('dt'):
        rating = item.text.strip()[6:]
        if (rating[0].isalnum() == False):
            rating = rating[6:]
            rating = rating.split('s')[0].strip()
        else:
            rating = np.nan
        ratings.append(rating)        
    temp_df['Rating'] = ratings
    
    # Same as above, use splinter browser to gather dynamic html content
    rating_counts = []
    for item in br.find_by_tag('dd'):
        counts = item.text.strip('()')
        rating_counts.append(counts)
    temp_df['Rating_Count'] = rating_counts
    
    br.quit()
    
    return temp_df

# %%
# Create a dataframe to store data in
shoes_df = pd.DataFrame(columns = ['Shoe_Name', 'Shoe_Company', 'Current_Price', 'Original_Price', 'Discount', 'Product_Link'])

# Define the primary url
master_url = 'https://www.rei.com/c/mens-climbing-shoes?page='
num = 1
link = master_url + str(num)

while requests.get(link).status_code != 404:
    link = master_url + str(num)
    shoes_df = pd.concat([shoes_df, scrape_rei(link)], axis = 0, ignore_index = True)
    num = num + 1

# %%
def scrape_product(link):
    # Make a request to the primary url and uses an html parser to gather data
    req = requests.get(link)
    soup = bs4.BeautifulSoup(req.text, 'html.parser')
    
    print(soup.find_all('div'))
        
    print(soup.find('p', {'class': 'product-primary-description'}))

# %%
scrape_product(shoes_df['Product_Link'].iloc[0])
# Out:
# [<div class="off-canvas-wrap" id="container">
# <div id="browserUpgrade"></div>
# <div class="inner-wrap">
# <header class="site-header" id="headerWrapper" role="banner">
# <div class="unav-wrap" data-ui="unav-container" id="js-unav-wrap">
# <nav aria-label="primary" class="unav" id="js-unav">
# <ul class="items">
# <li class="item skip-link--accessibility unav-skip-link sr-only" data-skip-show="accessibility-statement">
# <a data-skip-link="accessibility-statement" href="https://www.rei.com/accessibility">
#           REI Accessibility Statement
#         </a>
# </li>
# <li class="item skip-link--main-content unav-skip-link sr-only" data-skip-show="content">
# <a data-skip-link="content" href="#page-content">
#           Skip to main content
#         </a>
# </li>
# <li class="item skip-link--secondary-nav unav-skip-link sr-only" data-skip-show="secondary-nav">
# <a data-skip-link="secondary-nav" href="#secondary-nav">Skip to Shop REI categories</a>
# </li>
# <li class="item active">
# <a aria-label="Current Page: Shop REI" data-analytics-id="universal_nav:shop rei" data-ui="unav-link" href="/">Shop REI</a>
# </li>
# <li class="item">
# <a data-analytics-id="universal_nav:rei garage" data-ui="unav-link" href="/rei-garage">REI Outlet</a>
# </li>
# <li class="item">
# <a data-analytics-id="universal_nav:used gear" data-ui="unav-link" href="/used">Used Gear</a>
# </li>
# <li class="item">
# <a data-analytics-id="universal_nav:rei adventures" data-ui="unav-link" href="/adventures">REI Adventures</a>
# </li>
# <li class="item">
# <a data-analytics-id="universal_nav:classes &amp; events" data-ui="unav-link" href="/events">Classes &amp; Events</a>
# </li>
# <li class="item">
# <a data-analytics-id="universal_nav:expert advice" data-ui="unav-link" href="/learn/expert-advice">Expert Advice</a>
# </li>
# <li class="item">
# <a data-analytics-id="universal_nav:co-op journal" data-ui="unav-link" href="/blog">Co-op Journal</a>
# </li>
# <li class="item">
# <a data-analytics-id="universal_nav:conversations" data-ui="unav-link" href="https://conversations.rei.com">Conversations</a>
# </li>
# <li class="item membership-unav">
# <span>•</span>
# <a data-analytics-id="universal_nav:membership" data-ui="unav-link" href="/membership/benefits">Membership</a>
# </li>
# </ul>
# </nav>
# </div>
# <style>
#     #js-unav li.item.membership-unav{
#         display: inline-flex;
#     }
#     #js-unav .item.membership-unav span{
#         align-self: center;
#         color: #fff;
#     }
# </style><script>
#     window.useNewMinicart = true;
#     </script>
# <script data-client-store="analytics" type="application/json">{"useTealiumForMarin":"false","useTealiumSync":"true","isRedesign":"true","siteCatalystEnabled":"false","testAndTargetLibraryUrl":"\/\/satchel.rei.com\/packages\/adobe-target\/at-v2.2.0.js","testAndTargetEnabled":"true","useAdobeTargetLibraryUrl":null,"slothEnabled":"true","useClientContextService":"true","targetPerformanceMetricsEnabled":"true","tealiumSyncLibraryURL":"\/\/satchel.rei.com\/packages\/tealium\/utag.sync-4.4.0.js","tealiumEnabled":"true","tealiumLibraryURL":"\/\/tags.tiqcdn.com\/utag\/rei\/main\/prod\/utag.js"}</script><script data-client-store="app-props" type="application/json">{"useEmailAcq":"true","performanceDeferRR":"true","asyncBannerSourceURL":"https:\/\/satchel.rei.com\/media\/global\/async-banner.html","emailAcqSitekey":"6LdGCh8UAAAAAI78ftxgsyMBmlXMQMnuLSpNI8vI","useHandlebars":"true","useAsyncBanner":"false","performanceDeferTealium":"true"}</script><script data-client-store="emailAcq" type="application/json">{"supressEmailAcq":null}</script><script data-client-store="minicart-messages" type="application/json">{"minicartShippingMessagePrimary":"FREE SHIPPING","cartRelPath":"\/ShoppingCart","minicartShippingMessageSecondary":"<a href=\"\/terms\/free-shipping\">With $50 minimum purchase.<\/a>","checkoutRelPath":"\/CheckoutLoginView","loginRelPath":"\/YourAccountLoginView"}</script><div class="site-header-inner container" data-ui="site-header"> <div class="site-header-masthead"> <div class="site-header-logo pull-left"> <div class="site-header-logo-inner"> <a data-analytics-id="rei_utilitylinks_logo" data-ui="site-header-logo" href="/"> <img alt="Go to REI.com Home Page" class="svg-logo" src="//satchel.rei.com/media/img/header/rei-co-op-logo-white.svg"/> </a> </div></div> <div class="site-header-body"> <div class="header-actions"> <div class="header-actions-user pull-right"> <ul class="masthead-actions"> <li class="cart"> <a class="js-cart-action wrapper-nav-link" data-analytics-id="rei_utilitylinks_cart" data-ui="shopping-cart-link" href="/ShoppingCart"> <span class="sr-only">Cart</span> <i class="empty js-cart-icon-empty"></i> <i class="full hidden js-cart-icon-full"></i> <div class="count js-cart-count-wrapper"> <span class="js-cart-count" data-ui="cart-item-count"></span> </div> </a> </li> <li class="burger"> <button class="js-burger" data-analytics-id="rei_utilitylinks_menu" data-state="close" data-ui="site-header-action-menu" type="button"> <span class="sr-only">Menu</span><i></i> </button> </li> </ul> </div> <div class="header-actions-search"> <div class="site-header-search" data-ui="submit-search-term"> <form action="/search" class="form-inline icon-label" method="GET" name="psearch" role="search"> <div class="form-group"> <div class="input-group"> <input aria-labelledby="searchbutton" autocorrect="off" class="search-box form-control form-control-input" data-ui="site-header-site-search-input" id="inputGroup" maxlength="70" name="q" placeholder="Search for great gear &amp; clothing" title="search input field" type="search"/> <span class="input-group-btn"> <button class="btn search-button" data-ui="search-button" id="searchbutton" title="Search"> <span class="sr-only">Search</span> <span aria-hidden="true" class="icon icon-rei-search pull-left"></span> </button> </span> </div> </div> </form> </div> </div> </div> <hr class="hidden-sm hidden-xs"/> <div class="header-nav-container"> <nav data-ui="site-navigation" role="navigation"> <ul class="actions"> <li class="sign-in"> <a aria-controls="sign-in-container" aria-expanded="false" class="wrapper-nav-link js-sign-in" data-ui="login-module-greeting" href="/YourAccountInfoInView" rel="nofollow"> <span class="sign-in-txt">Sign in</span><span class="my-account-txt">My account</span><i></i> </a> </li> <li class="sign-in-dropdown" data-ui="login-module"> <div id="sign-in-container"> <div class="mtns"> <svg aria-hidden="true" class="twin-peaks-svg-container__twin-peaks-svg" height="19" version="1.0" ...
# <div id="nav-promo">
# <style>
# #nav-promo-4f157df3-aa2e-4d7a-a4c5-a1d1129a93b8{
#     padding: 8px;
#     background-color: #C00;
#
# }
#
# .nav-promo-link-4f157df3-aa2e-4d7a-a4c5-a1d1129a93b8{
#   color: #ffffff!important;
# }
#
# .nav-promo_copy {
#     font-size: 1.4rem;
# </style>
# <div id="nav-promo-4f157df3-aa2e-4d7a-a4c5-a1d1129a93b8">
# <div class="container text-center">
# <a data-analytics-id="nav-promo-sale" href="/h/labor-day-sale">
# <div class="nav-promo-link-4f157df3-aa2e-4d7a-a4c5-a1d1129a93b8">
# <span class="col-xs-12 nav-promo_copy"><strong>Save up to 40%</strong> during our Labor Day Sale &amp; Clearance thru 9/7. <u><strong>Shop now</strong></u></span>
# </div>
# </a>
# </div>
# </div>
# </div>
# <div class="container rei-page-content" data-page-config-canonical-path="" data-ui="page-content" id="page-content" role="main">
# <script data-client-store="product-metadata" type="application/json">
# {
#     "isProd": "true",
#     "breadcrumbCats": [{"id":"products","label":"Products","link":"/c/products","guid":"e148634f-d1ea-4ddf-be55-270849efd0d6"},{"id":"climbing","label":"Climbing","link":"/c/climbing","guid":"ab3b6fd3-3329-42ee-835a-7875bc8fba95"},{"id":"climbing-shoes","label":"Climbing Shoes","link":"/c/climbing-shoes","guid":"1d24e787-ee58-4a0d-9e38-afa935a4d296"},{"id":"mens-climbing-shoes","label":"Men\u0027s Climbing Shoes","link":"/c/mens-climbing-shoes","guid":"9b0a7a43-10cc-4bc8-829f-5f96a01abe7e"}],
#     "brandName": "Five Ten",
#     "brandLogo": "https://satchel.rei.com/media/img/brand-logos/five-ten.png",
#     "brandPath": "/b/five-ten",
#     "isPup": false,
#     "isBrandAvailable": true,
#     "isBrandCatAvailable": true,
#     "primaryCategoryLink": "/c/mens-climbing-shoes",
#     "primaryCategoryLabel": "Men\u0027s Climbing Shoes",
#     "title":  "Rogue VCS Climbing Shoes - Men\u0027s",
#     "shortDesc": "Built with the basics in mind for beginning climbers, the men\u0027s Five Ten Rogue VCS climbing shoes will help you develop precise footwork and build foot strength for long practice sessions in the gym.",
#     "itemNumber": "170687",
#     "isEligibleForPickUp": true,
#     "relatedLinks": []
# }
# </script>
# <script data-client-store="product-app-props" type="application/json">
# {
#     "disableColorSwatches": "false",
#     "UgcRatingEnabled": "true",
#     "enableBV": "true",
#     "enableNewRelicBVTracking": "true",
#     "enableBVReviewHighlights": "false",
#     "enableBVReviewHighlightsLocation": null,
#     "enableBVReviewHighlightsEndpoint": "https://apps.bazaarvoice.com/deployments/rei-inc/main_site/production/en_US/bv.js",
#     "modelFitProperties": "Chest,Waist,Inseam",
#     "mrOnPDP": "true",
#     "mrSrc": "//www.myregistry.com/ScriptPlatform/API/AddButtonSDK.js?siteKey\u003dshhf1KNnchnshuNnQcDV3A2",
#     "zoomEnabled": "true",
#     "useATCModal": "true",
#     "plaGiftCardExperience": "A",
#     "useRRRelatedItems": "true",
#     "bonusCardCopy": "bonus card included with order",
#     "useNPMRecs": "true",
#     "useRRLoadScript": "true",
#     "useSizeColorVue": "true",
#     "alwaysLoadPLA": "false",
#     "rrPlacementNames": {"PUPProductRecs":"item_page.ProductUnavailable1","PrimaryProductRecs":"item_page.BottomPageHorizontal","RelatedProductRecs":"item_page.CoreRelatedItems","AddToCartProductRecs":"add_to_cart_page.CoreAddtoCart","PLAProductRecs":"item_page.PLA1"},
#     "isColorByPrice": "true",
#     "showSustainability": "true",
#     "showSustainabilityBadge": "true",
#     "sustainabilityCategories": {"RESPONSIBLE_DOWN":"(Down Standard)","BLUESIGN":"(bluesign)","LEATHER_WORKING_GROUP":"(Leather Working Group)","FAIR_TRADE":"(Fair Trade Certified|Fairtrade)","FOREST_STEWARDSHIP":"(Forest Stewardship Council)","RECYCLED":"(recycled)","ORGANIC":"(organic)","RESPONSIBLE_WOOL":"(Responsible Wool Standard)"},
#     "styles360": {"128692":"https://rei360.sirv.com/Spins/HalfDome2Plus_NoFly/HalfDome2Plus_NoFly.spin","163527":"https://rei360.sirv.com/Spins/7023BreezeATGTX/7023BreezeATGTX.spin","163526":"https://rei360.sirv.com/Spins/7023BreezeATGTX/7023BreezeATGTX.spin","164226":"https://rei360.sirv.com/Spins/WestwindsGTXJacket-Blue/WestwindsGTXJacket-Blue.spin","168251":"https://rei360.sirv.com/Spins/Trailbreak60Pack/Trailbreak60Pack.spin","166445":"https://rei360.sirv.com/Spins/Habit4AL29/Habit4AL29.spin","166476":"https://rei360.sirv.com/Spins/QuickNeoSL2/QuickNeoSL2.spin","164200":"https://rei360.sirv.com/Spins/WestwindsGTXJacket-Oran/WestwindsGTXJacket-Oran.spin","166583":"https://rei360.sirv.com/Spins/LonePeak45/LonePeak45.spin","136291":"https://rei360.sirv.com/Spins/Bondi6Gray/Bondi6Gray.spin","148589":"https://rei360.sirv.com/Spins/Flash55Pack/Flash55Pack.spin","110819":"https://rei360.sirv.com/Spins/QuarterDome2_multiangle/QuarterDome2_multiangle.spin","134161":"https://rei360.sirv.com/Spins/OutlinelowGTX/OutlinelowGTX.spin","136295":"https://rei360.sirv.com/Spins/Bondi6Green/Bondi6Green.spin"},
#     "show360Image":  "true",
#     "isSizingExposed": "true",
#     "disablePickup": "false",
#     "storePickupLabel": "Pick up at store",
#     "showCurbsidePickup": "true",
#     "curbsideInfoBopus": "Most stores now offer Curbside Pickup with zero contact",
#     "curbsideInfoShippingOptions": "Curbside Pickup available at select locations.",
#     "noInstorePickupText": "Our stores are temporarily closed."
# }
# </script>
# <script data-client-store="product-price-data" type="application/json">
# {
#     "compareAt": 100,
#     "min": 39.93,
#     "max": 39.93,
#     "notBuyableOnly": false,
#     "isPriceHidden": false
# }
# </script>
# <script data-client-store="message-data" type="application/json">
# {
#     "freeShipping": false,
#     "isOverSize": false,
#     "messages": [{"type":"Shipping","message":"Orders of $50 or more ship for free. \n\u003ca href\u003d\"/terms/free-shipping\" class\u003d\"member\" id\u003d\"memberFreeShipLnk\"\u003eLearn more\u003c/a\u003e","internalRuleName":"freeShipping"},{"type":"DiscountAndPromotion","message":"HURRY! Clearance quantities limited. Shop now for best selection.","internalRuleName":"message:clearance"}],
#     "oversizeChargeSizeMap": {},
#     "shippingMessaging": {
#         "free": "This item ships for FREE!",
#         "freeToStore": "Shipping is FREE with REI Store Pickup.",
#         "almostFree": "Orders of $50 or more ship for free."
#     },
#     "isRSPUOnly": false,
#     "isRSPUForSelectStores": false,
#     "isRSPUForAllStores": false,
#     "suppressOversizeMesg": false,
#     "isHazardous": false,
#     "isBackOrder": false,
#     "isPreOrder": false,
#     "vifEnabled": "true",
#     "hasSkuShippingRestriction": false,
#     "styleShippingRestrictions": [],
#     "atcDeliveryErrorMsg": "This item is currently unavailable due to shipping restrictions and store closures."
# }
# </script>
# <script data-client-store="campaign-data" type="application/json">
#     {
#         "campaignMessagesMap": {},
#         "productMemberMinEndDate": "the 2015/16 season.",
#         "memberOnlyActive": false,
#         "memberFirstActive": false
#     }
# </script>
# <script data-client-store="inventory-data" type="application/json">
#     {
#         "preOrderActive": false,
#         "notBuyableActive": false,
#         "comingSoonText": "Check back soon."
#     }
# </script>
# <script data-client-store="image-data" type="application/json">
#     {
#         "id": "170687",
#         "media": [{"mediaId":"ab5f1b4b-3e80-4c74-aabb-111079e900e0","styleId":"170687","color":{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"},"typeId":1,"type":"Product Image","maxHeight":1160,"maxWidth":2496,"status":"PUBLISHED","featured":true,"uri":"/media/ab5f1b4b-3e80-4c74-aabb-111079e900e0","skuId":"1706870010","modelMeasurements":[],"swatchColors":["#1C1E20"]},{"mediaId":"e889fb16-802f-401c-8c38-fc12046d6a82","styleId":"170687","color":{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"},"typeId":2,"type":"Detail Image","maxHeight":1032,"maxWidth":1976,"status":"PUBLISHED","uri":"/media/e889fb16-802f-401c-8c38-fc12046d6a82","skuId":"1706870010","modelMeasurements":[],"swatchColors":["#1C1E20"]},{"mediaId":"7476a45f-d4e8-4465-b6b5-9fcddfc50cd7","styleId":"170687","color":{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"},"typeId":2,"type":"Detail Image","maxHeight":1616,"maxWidth":1992,"status":"PUBLISHED","uri":"/media/7476a45f-d4e8-4465-b6b5-9fcddfc50cd7","skuId":"1706870010","modelMeasurements":[],"swatchColors":["#1C1E20"]},{"mediaId":"7a6611f9-f639-4f49-be15-26e903dcbf88","styleId":"170687","color":{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"},"typeId":2,"type":"Detail Image","maxHeight":1674,"maxWidth":2008,"status":"PUBLISHED","uri":"/media/7a6611f9-f639-4f49-be15-26e903dcbf88","skuId":"1706870010","modelMeasurements":[],"swatchColors":["#1C1E20"]},{"mediaId":"32676b03-5f7c-4420-aaa2-7f39a4cdf3ab","styleId":"170687","color":{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"},"typeId":2,"type":"Detail Image","maxHeight":2504,"maxWidth":872,"status":"PUBLISHED","uri":"/media/32676b03-5f7c-4420-aaa2-7f39a4cdf3ab","skuId":"1706870010","modelMeasurements":[],"swatchColors":["#1C1E20"]},{"mediaId":"bfd0223d-ffba-4989-a71b-ec87a6943334","styleId":"170687","color":{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"},"typeId":2,"type":"Detail Image","maxHeight":2488,"maxWidth":875,"status":"PUBLISHED","uri":"/media/bfd0223d-ffba-4989-a71b-ec87a6943334","skuId":"1706870010","modelMeasurements":[],"swatchColors":["#1C1E20"]}],
#         "showSwatches": false,
#         "showAllDetailImages": true,
#         "articleBadgeMap": {"MEMBER_ONLY":false,"ONLINE_ONLY":false,"CYCLING":false,"PRIVATE_BRANDS":false,"ONLY_AT_REI":false,"MEMBER_FIRST":false,"OSPREY":false},
#         "badgeMap": ["HAND_PICKED","ONLY_AT_REI","ONLINE_ONLY","BACKPACKERS_EDITORS_CHOICE"],
#         "fullTitle": "Five Ten Rogue VCS Climbing Shoes - Men\u0027s",
#         "badgeImgMap": {"BACKPACKERS_EDITORS_CHOICE":"https://satchel.rei.com/media/product/ED_CHOICE_2018_v1.svg","ONLINE_ONLY":"/pix/product/badges/online-only-badge.svg","STAFF_PICK":"https://satchel.rei.com/media/product/staff-pick-badge.svg","ONLY_AT_REI":"https://satchel.rei.com/media/product/CO-OP_Exclusive_Horizontal.svg","HAND_PICKED":"/pix/product/badges/first-to-market-badge.svg"},
#         "userManuals": []
#     }
# </script>
# <script data-client-store="video-data" type="application/json">
#     {
#         "videos": [],
#         "displayVideos": "true"
#     }
# </script>
# <script data-client-store="product-details" type="application/json">
#     {
#         "features": ["Built with the basics in mind for beginning climbers, the men\u0027s Five Ten Rogue VCS climbing shoes will help you develop precise footwork and build foot strength for long practice sessions in the gym.","4.2mm Stealth® C4™ ultra-sticky rubber outsoles grip nearly every surface and provide good edging for smearing and climbing in the gym","Partially lined leather uppers have hook-and-loop straps to adjust and secure the fit","Supportive midsoles promote increased feeling and sensitivity; shoes offer medium stiffness","Rogue VCS shoes are built on the same last as the popular Anasazi climbing shoes"],
#         "specs": [{"name":"Best Use","values":["Rock Climbing"],"displayOrder":1,"code":50},{"name":"Climbing Shoe Type","values":["Neutral"],"displayOrder":2,"featuredSpecificationDisplayOrder":1,"code":619},{"name":"Last","values":["Slip-lasted"],"displayOrder":3,"featuredSpecificationDisplayOrder":2,"code":395},{"name":"Upper","values":["Split-grain rubber"],"displayOrder":4,"featuredSpecificationDisplayOrder":4,"code":742},{"name":"Lining","values":["Stretch arch lining"],"displayOrder":5,"code":419},{"name":"Outsole","values":["Stealth® C4 rubber"],"displayOrder":6,"code":488},{"name":"Footwear Closure","values":["Strap"],"displayOrder":7,"code":807},{"name":"Can Be Resoled","values":["Yes"],"displayOrder":8,"featuredSpecificationDisplayOrder":3,"code":164},{"name":"Gender","values":["Men\u0027s"],"displayOrder":10,"code":51},{"name":"Weight (Pair)","values":["15.5 ounces"],"displayOrder":11,"code":767}],
#         "sizes": [],
#         "featuredSpecs": [{"name":"Climbing Shoe Type","values":["Neutral"],"displayOrder":2,"featuredSpecificationDisplayOrder":1,"code":619},{"name":"Last","values":["Slip-lasted"],"displayOrder":3,"featuredSpecificationDisplayOrder":2,"code":395},{"name":"Can Be Resoled","values":["Yes"],"displayOrder":8,"featuredSpecificationDisplayOrder":3,"code":164},{"name":"Upper","values":["Split-grain rubber"],"displayOrder":4,"featuredSpecificationDisplayOrder":4,"code":742}],
#         "reviewsSummary": {"styleId":"170687","total":6,"overall":4.5000,"maxRange":5,"ratingHistogram":{"1":0,"2":0,"3":1,"4":1,"5":4},"wouldRecommendCount":0,"wouldNotRecommendCount":0},
#         "sellingCopy": "",
#         "countryOfOrigin": "Made in USA.",
#         "relatedAccessories": [],
#         "productZone1": "",
#         "productZone2": "",
#         "carouselVal": "Horizontal",
#         "sizeLabel": "Size",
#         "colorLabel": "Color",
#         "brand": "Five Ten",
#         "brandName": "five-ten",
#         "showBrandDesc": "true"
#     }
# </script>
# <div id="product-loading">
# <img alt="loading animation" src="https://satchel.rei.com/media/global/img/compass-animation-222.gif"/>
# </div>
# <div class="product-wrapper rich-display" id="product-wrapper">
# <div class="alert alert-danger hidden employee-review-message" role="alert">
# <span aria-hidden="true" class="icon icon-rei-error"></span>
# <span class="alert-text">
# <span class="sr-only">Error:</span>
#         REI employees are not permitted to submit reviews or Q&amp;A at this time.
#     </span>
# </div><div class="pla-content-holder hidden" data-ui="pla-content-holder">
# <div data-image-size="80" data-num-recommendations="6" data-placement-type="item_page.PLA1">
# <script type="text/x-handlebars-template">
#       		<div class="recommendations-component rei-recs">
#           		<h3>Looking for something else?</h3>
#           		<div class="row">
# 		  			<div class="col-xs-12 col-md-9">
#               			<div class="pla-carousel-container">
#                 			<div class="carousel-slides">
#                   			{{#each correlations}}
#                   				<div class="item{{#if @first}} active{{/if}}">
#                    	 				<div class="product-tile">
#                       					<a
#                         					href="{{extract-pdp-url linkURL}}"
#                         					class="product-link"
#                                             data-rr-url="{{linkURL}}"
# 																	data-ui="recommended-product-link"
# 																	data-analytics-info="{{build-analytics-info ../vertical ../placementName ../strategyMessage id ../strategy @index}}"
# 																>
# 					              			<div class="pdt-tile">
# 						              			<div class="pdt-img" >
#                           							<img src="{{build-image-url id ../imageSize}}"  class="img-responsive center-block" />
#                       	  						</div>
#                       	  						<div class="pdt-info">
# 							              			<div class="title" alt="{{brand}}" title="{{brand}}">{{brand}}</div>
#                           							<div class="product-name" alt="{{fetch-product-name brand name}}"
# 														 title="{{fetch-product-name brand name}}">{{{line-clamp-text (fetch-product-name brand name) 40}}}</div>
#                           							{{#if displaySalePrice}}
#                           							<div class="price">
#                             							<span class="sale-price">{{displaySalePrice}}</span>
#                             							<span class="compare-at-price">{{compareAtPrice}}</span>
#                           							</div>
#                           							{{else}}
#                           							<span class="recs-product-price price">{{displayPrice}}</span>
#                           							{{/if}}
#                       	  						</div>
# 					              			</div>
#                       					</a>
#                     				</div>
#                   				</div>
#                   			{{/each}}
#                 			</div>
# 		          		</div>
#               			<a class="prev hidden-xs hidden-sm" ><span class="icon icon-rei-left-arrow"></span></a>
#               			<a class="next hidden-xs hidden-sm" ><span class="icon icon-rei-right-arrow"></span></a>
#             		</div>
#             		<div class="hidden-sm hidden-xs col-md-3">
# 									<div class="rr-gift-card pdt-cat related-categories hidden">
# 											<div class="title">Related Categories</div>
# 													<div class="link"><a href="/c/mens-climbing-shoes"
# 										data-analytics-id="topRecs_Related product categories_Men's Climbing Shoes">Men's Climbing Shoes</a></div>
# 													<div class="link">
# 															<a  href="/b/five-ten/c/mens-climbing-shoes"
# 											data-analytics-id="topRecs_Related product categories_Five TenMen's Climbing Shoes">
# 											Five Ten&nbsp;Men's Climbing Shoes</a>
# 													</div>
# 													</div>
# 									<div class="rr-gift-card rr-gift-card-link hidden">
# 										<div class="rr-gift-card-content">
# 											<div class="title">Give the gift of the outdoors.</div>
# 											<div class="link"><a class="buy-gift-card-link" href="/gift-card/purchase" title="Buy an REI Gift Card" alt="Buy an REI Gift Card">Buy an REI Gift Card</a></div>
# 										</div>
# 									</div>
# 									<div class="rr-gift-card rr-gift-card-img hidden">
# 										<a class="buy-gift-card-link" href="/gift-card/purchase"><img src="//satchel.rei.com/media/product/rr-gift-card.png" title="Buy an REI Gift Card" alt="Buy an REI Gift Card"/></a>
# 										<div class="link"><a class="buy-gift-card-link" href="/gift-card/purchase" title="Buy an REI Gift Card" alt="Buy an REI Gift Card">Buy an REI Gift Card</a></div>
# 									</div>
#             		</div>
#           		</div>
#           		<hr/>
#         		<div class="rounded-bottom close-pla" data-analytics-id="topRecs_close">
#           			<span class="icon icon-rei-close-small"></span>
#         		</div>
#       		</div>
#     	</script>
# </div>
# </div>
# <div class="row">
# <section class="banner col-xs-12" data-ui="product-banner-component">
# <div data-is="inventory-banners"></div>
# <div data-is="campaign-banners"></div>
# </section></div>
# <div class="loading-buybox hidden">
# <img alt="loading animation" src="https://satchel.rei.com/media/global/img/compass-animation-222.gif"/>
# </div>
# <div aria-hidden="true" class="hidden" data-ui="aggregate-rating">
# </div>
# <div class="row apparel-pdp" id="product-container">
# <div class="col-xs-12 product-header-elements-wrapper">
# <nav aria-label="Breadcrumb" data-analytics-default-page-name="rei:product details:Five Ten Rogue VCS Climbing Shoes - Men's_170687" data-analytics-tag-prefix="cm_sp-_-pagecontent-_-" data-is="breadcrumbs"></nav>
# <div class="product-brand-link" data-is="product-brand-link" placement-above-media-center="true"></div>
# </div>
# <div class="col-xs-12">
# <div class="row">
# <div class="col-xs-12 col-md-8 product-media-wrapper apparel-media-wrapper">
# <div class="product-title" data-is="product-title"></div>
# <div class="row row-flex product-info-wrapper-sm">
# <div class="col-xs-7 product-rating-wrapper hidden-md hidden-lg" data-ui="product-rating-component">
# <div class="product-rating-navigable offset-bv-summary-review">
# <div id="ugc-rating-summary-mobile"></div>
# </div>
# </div>
# <div class="col-xs-5 no-gutter hidden-md hidden-lg" data-is="item-number"></div>
# </div>
# <div data-is="apparel-media-center" data-ui="apparel-media-image-container"></div>
# </div>
# <div class="col-xs-12 col-md-4 product-buy-wrapper">
# <div class="row row-flex product-info-wrapper cdr-pb-space-half-x">
# <div class="col-xs-7 product-rating-wrapper offset-bv-summary-review hidden-xs hidden-sm" data-ui="product-rating-component" id="bv2-desktop">
# <div class="product-rating-navigable">
# <div id="ugc-rating-summary-desktop"></div>
# </div>
# </div>
# <div class="col-xs-5 no-gutter hidden-xs hidden-sm" data-is="item-number"></div>
# </div>
# <div class="product-price-wrapper" data-is="price" data-ui="product-price-component" price-id="js-product-information-price"></div>
# <div class="message-wrapper">
# <div class="hidden-xs hidden-sm" data-is="shipping" placement="desktop"></div>
# <div data-is="member-and-price-messaging" default_pagename="rei:product details:Five Ten Rogue VCS Climbing Shoes - Men's_170687" estimated_savings="" from_url="/product/170687/five-ten-rogue-vcs-climbing-shoes-mens" is_clearance="true" is_sale="false" show_dividend_message="false" tag_prefix="cm_sp-_-pagecontent-_-">
# </div>
# </div>
# <div class="product-buyable-area active">
# <section class="buy-grid">
# <form action="/AddItemToCartController" class="purchasing-form" id="purchasing-form" method="post" name="additem" novalidate="">
# <input id="vendor" name="vendor" type="hidden" value="Five Ten"/>
# <input name="itemNumber" type="hidden" value="170687"/>
# <input name="style" type="hidden" value="170687"/>
# <input name="product_desc" type="hidden" value="Five Ten Rogue VCS Climbing Shoes - Men's"/>
# <input name="fromUrl" type="hidden" value="/product/170687"/>
# <input name="currency" type="hidden" value="USD"/>
# <input name="storeId" type="hidden" value="8000"/>
# <input name="available_skus" type="hidden" value="N"/>
# <input name="splashCategory" type="hidden" value=""/>
# <div class="user-selection form-group">
# <div class="product-color-and-size-selection" data-ui="product-color-size-component">
# <div class="row">
# <div class="col-xs-12" data-is="size-color" force-size="true" is_retail_only="false"></div>
# <div class="col-xs-12 size-color-vue" force-size="true" is_retail_only="false"></div>
# </div>
# <div data-is="sku-select" is_hidden="true"></div>
# <script data-client-store="product-model-data" type="application/json">
#     {
#         "sizeChartUrl": "",
#         "sizeList": [{"label":"2","colors":[{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"}]},{"label":"2.5","colors":[{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"}]},{"label":"3","colors":[{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"}]},{"label":"3.5","colors":[{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"}]},{"label":"5.5","colors":[{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"}]},{"label":"6","colors":[{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"}]},{"label":"6.5","colors":[{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"}]},{"label":"7","colors":[{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"}]},{"label":"7.5","colors":[{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"}]},{"label":"8","colors":[{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"}]},{"label":"8.5","colors":[{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"}]}],
#         "ANALYT_DEFAULT_PAGENAME": "rei:product details:Five Ten Rogue VCS Climbing Shoes - Men&#039;s_170687",
#         "labels": {
#             "color": "Color",
#             "size": "Size"
#         },
#         "splashCategory": null,
#         "showDropdown": false,
#         "variants": [{"sku":"1706870001","quantity":0,"size":"2","isAvailable":true,"isBackordered":false,"status":"AVAILABLE","price":39.93,"sellingPrice":39.93,"compareAtPrice":100,"hideDisplayPrice":false,"color":{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"},"identifiers":[{"type":"UPC","value":"612558167229","primary":true}],"manufacturersPartNumber":"5102-2","skuCost":20,"shippingTier":1,"isOverSize":false,"isHazardous":false,"isGiftWrappable":true,"casemark":"5102-2","isSkuOnSale":false,"assemblyRequired":false,"salesUnitOfMeasure":"EA","campaigns":[],"isMap":false,"merchStatus":"D","restrictions":[]},{"sku":"1706870002","quantity":0,"size":"2.5","isAvailable":true,"isBackordered":false,"status":"AVAILABLE","price":39.93,"sellingPrice":39.93,"compareAtPrice":100,"hideDisplayPrice":false,"color":{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"},"identifiers":[{"type":"UPC","value":"612558167236","primary":true}],"manufacturersPartNumber":"5102-2.5","skuCost":20,"shippingTier":1,"isOverSize":false,"isHazardous":false,"isGiftWrappable":true,"casemark":"5102-2.5","isSkuOnSale":false,"assemblyRequired":false,"salesUnitOfMeasure":"EA","campaigns":[],"isMap":false,"merchStatus":"D","restrictions":[]},{"sku":"1706870003","quantity":0,"size":"3","isAvailable":true,"isBackordered":false,"status":"AVAILABLE","price":39.93,"sellingPrice":39.93,"compareAtPrice":100,"hideDisplayPrice":false,"color":{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"},"identifiers":[{"type":"UPC","value":"612558167243","primary":true}],"manufacturersPartNumber":"5102-3","skuCost":20,"shippingTier":1,"isOverSize":false,"isHazardous":false,"isGiftWrappable":true,"casemark":"5102-3","isSkuOnSale":false,"assemblyRequired":false,"salesUnitOfMeasure":"EA","campaigns":[],"isMap":false,"merchStatus":"D","restrictions":[]},{"sku":"1706870004","quantity":0,"size":"3.5","isAvailable":true,"isBackordered":false,"status":"AVAILABLE","price":39.93,"sellingPrice":39.93,"compareAtPrice":100,"hideDisplayPrice":false,"color":{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"},"identifiers":[{"type":"UPC","value":"612558167250","primary":true}],"manufacturersPartNumber":"5102-3.5","skuCost":20,"shippingTier":1,"isOverSize":false,"isHazardous":false,"isGiftWrappable":true,"casemark":"5102-3.5","isSkuOnSale":false,"assemblyRequired":false,"salesUnitOfMeasure":"EA","campaigns":[],"isMap":false,"merchStatus":"D","restrictions":[]},{"sku":"1706870007","quantity":0,"size":"5.5","isAvailable":true,"isBackordered":false,"status":"AVAILABLE","price":39.93,"sellingPrice":39.93,"compareAtPrice":100,"hideDisplayPrice":false,"color":{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"},"identifiers":[{"type":"UPC","value":"612558167298","primary":true}],"manufacturersPartNumber":"5102-5.5","skuCost":20,"shippingTier":1,"isOverSize":false,"isHazardous":false,"isGiftWrappable":true,"casemark":"5102-5.5","isSkuOnSale":false,"assemblyRequired":false,"salesUnitOfMeasure":"EA","campaigns":[],"isMap":false,"merchStatus":"D","restrictions":[]},{"sku":"1706870008","quantity":0,"size":"6","isAvailable":true,"isBackordered":false,"status":"AVAILABLE","price":39.93,"sellingPrice":39.93,"compareAtPrice":100,"hideDisplayPrice":false,"color":{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"},"identifiers":[{"type":"UPC","value":"612558167304","primary":true}],"manufacturersPartNumber":"5102-6","skuCost":20,"shippingTier":1,"isOverSize":false,"isHazardous":false,"isGiftWrappable":true,"casemark":"5102-6","isSkuOnSale":false,"assemblyRequired":false,"salesUnitOfMeasure":"EA","campaigns":[],"isMap":false,"merchStatus":"D","restrictions":[]},{"sku":"1706870009","quantity":0,"size":"6.5","isAvailable":true,"isBackordered":false,"status":"AVAILABLE","price":39.93,"sellingPrice":39.93,"compareAtPrice":100,"hideDisplayPrice":false,"color":{"code":"163675","label":"NEON BLUE/CHARCOAL","colorFamily":"Blue"}, ...
#         "sizeToColorList": [{"name":"2","displayName":"2","mapList":[{"name":"NEON BLUE/CHARCOAL","sku":"1706870001"}]},{"name":"2.5","displayName":"2.5","mapList":[{"name":"NEON BLUE/CHARCOAL","sku":"1706870002"}]},{"name":"3","displayName":"3","mapList":[{"name":"NEON BLUE/CHARCOAL","sku":"1706870003"}]},{"name":"3.5","displayName":"3.5","mapList":[{"name":"NEON BLUE/CHARCOAL","sku":"1706870004"}]},{"name":"5.5","displayName":"5.5","mapList":[{"name":"NEON BLUE/CHARCOAL","sku":"1706870007"}]},{"name":"6","displayName":"6","mapList":[{"name":"NEON BLUE/CHARCOAL","sku":"1706870008"}]},{"name":"6.5","displayName":"6.5","mapList":[{"name":"NEON BLUE/CHARCOAL","sku":"1706870009"}]},{"name":"7","displayName":"7","mapList":[{"name":"NEON BLUE/CHARCOAL","sku":"1706870010"}]},{"name":"7.5","displayName":"7.5","mapList":[{"name":"NEON BLUE/CHARCOAL","sku":"1706870011"}]},{"name":"8","displayName":"8","mapList":[{"name":"NEON BLUE/CHARCOAL","sku":"1706870012"}]},{"name":"8.5","displayName":"8.5","mapList":[{"name":"NEON BLUE/CHARCOAL","sku":"1706870013"}]}],
#         "colorToSizeList": [{"name":"NEON BLUE/CHARCOAL","displayName":"Neon Blue/Charcoal","imageUri":"/media/ab5f1b4b-3e80-4c74-aabb-111079e900e0","imageWidth":2496,"imageHeight":1160,"mapList":[{"name":"2","sku":"1706870001"},{"name":"2.5","sku":"1706870002"},{"name":"3","sku":"1706870003"},{"name":"3.5","sku":"1706870004"},{"name":"5.5","sku":"1706870007"},{"name":"6","sku":"1706870008"},{"name":"6.5","sku":"1706870009"},{"name":"7","sku":"1706870010"},{"name":"7.5","sku":"1706870011"},{"name":"8","sku":"1706870012"},{"name":"8.5","sku":"1706870013"}]}],
#         "sizeChartCount": 4,
#         "userSelectedSku": null,
#         "saveHistory": true
#     }
# </script>
# </div>
# <div data-is="inventory-messages" is_retail_only="false" is_single_sku="false" only_backorder_skus="false" only_preorder_skus="false">
# </div>
# <div data-is="low-inventory-message"></div>
# <div data-is="restriction"></div>
# <hr/>
# <div data-is="shipping-options"></div>
# <div class="alert-danger item-count-exceeded-error" data-ui="item-count-exceeded-error" role="alert">
# <span aria-hidden="true" class="icon icon-rei-error"></span>
# <span class="alert-text">
#                     You’ve reached the maximum items allowed in cart. Please check out and start a new order or call us at
#                     <a data-ui="list-group-item-phone" href="tel:18004264840">1-800-426-4840</a> to complete a transaction of more than 50 items.
#                 </span>
# </div>
# <div class="alert-danger registry-error" data-ui="registry-error" role="alert">
# <span aria-hidden="true" class="icon icon-rei-error"></span>
# <span class="alert-text">
#                     Looks like you'd like to order gifts from multiple registries (lucky them!). We can ship to only one address per order, so please complete any orders currently in your cart.</span>
# </div>
# </div>
# <div bopus_enabled="true" data-is="buy-buttons" data-ui="product-buybtn-component" is_retail_only="false" mr_on_pdp="true" only_preorder_skus="" show_membership_checkbox="false" show_siv="true">
# </div>
# </form>
# <form action="/wishlistAdd" id="addtowishlistform2" method="post" name="wishlist-form">
# <input class="required" id="wishlistQty" name="qty" type="hidden" value="">
# <input name="currency" type="hidden" value="USD">
# <input name="storeId" type="hidden" value="8000">
# <input name="fromURL" type="hidden" value="/product/170687">
# <input name="product_desc" type="hidden" value="Five Ten Rogue VCS Climbing Shoes - Men's">
# <input name="vendor" type="hidden" value="Five Ten">
# <input name="catalogId" type="hidden" value="40000008000">
# <input name="addToWishList" type="hidden" value="">
# <input name="URL" type="hidden" value="">
# <input id="id" name="id" type="hidden" value="">
# <input name="sku" type="hidden" value="">
# <input class="required" name="quantity" type="hidden" value="">
# </input></input></input></input></input></input></input></input></input></input></input></input></form>
# </section>
# </div>
# <div data-is="return-popover"></div>
# <div data-is="legal"></div>
# <div class="message-wrapper hidden-md hidden-lg">
# <div data-is="shipping" placement="mobile"></div>
# </div>
# <div data-is="intermediate-markdown"></div>
# <div data-is="product-zoom"></div>
# </div>
# </div>
# </div>
# </div>
# <div data-is="complete-the-look"></div>
# <div class="product-tabs-details">
# <div class="col-xs-12" data-is="description"></div>
# <div class="col-xs-12" data-is="product-featured-specs"></div>
# <div class="col-xs-12 col-md-10 col-md-offset-1" data-is="product-featured-banners" data-ui="product-featured-banners"></div>
# </div>
# <div class="row product-features-details" data-ui="features-details">
# <div class="col-xs-12 product-details-wrapper">
# <div class="product-features col-details" data-is="product-features" data-ui="product-features"></div>
# <div class="product-specs col-details" data-is="product-specs" data-ui="product-specs"></div>
# <div data-location="promo-and-manual-desktop">
# <div class="col-details product-promo-manual-container cdr-stack">
# <div class="user-manuals" data-is="user-manuals" data-ui="product-user-manuals"></div>
# <div class="promo-coupon" data-is="promo-coupons" data-ui="product-promo-coupon"></div>
# </div>
# </div>
# </div>
# <div class="col-xs-12" id="sustainability">
# <div class="sustainability" data-is="sustainability" data-ui="sustainability"></div>
# </div>
# <div data-location="recs-1-desktop"></div>
# <div class="col-xs-12" data-ui="product-tab-panel-recommendations" id="product-recommendations">
# <aside aria-labelledby="recommendations--pdp-1" class="recommendations--temp" data-ui="bottom-recs-showing">
# <div data-rec-zone="item_page.BottomPageHorizontal"></div>
# </aside>
# </div>
# <div aria-labelledby="product-size-chart" class="col-xs-12 js-product-description-pane" data-tab-selector="size-chart" data-ui="product-tab-panel-size-chart" id="product-size-chart" role="tabpanel">
# <h2 class="h3-override" data-name="size" tabindex="0">Size chart</h2>
# <div id="size-chart-container">
# <div class="table-responsive size-chart-table-container invisible">
# <table class="table table-striped table-bordered size-chart-table">
# <thead>
# <tr>
# <td class="size-chart-header"></td>
# <th class="size-chart-header" id="column0" scope="column">2</th>
# <th class="size-chart-header" id="column1" scope="column">2.5</th>
# <th class="size-chart-header" id="column2" scope="column">3</th>
# <th class="size-chart-header" id="column3" scope="column">3.5</th>
# <th class="size-chart-header" id="column4" scope="column">4</th>
# <th class="size-chart-header" id="column5" scope="column">4.5</th>
# <th class="size-chart-header" id="column6" scope="column">5</th>
# <th class="size-chart-header" id="column7" scope="column">5.5</th>
# <th class="size-chart-header" id="column8" scope="column">6</th>
# <th class="size-chart-header" id="column9" scope="column">6.5</th>
# <th class="size-chart-header" id="column10" scope="column">7</th>
# <th class="size-chart-header" id="column11" scope="column">7.5</th>
# <th class="size-chart-header" id="column12" scope="column">8</th>
# <th class="size-chart-header" id="column13" scope="column">8.5</th>
# <th class="size-chart-header" id="column14" scope="column">9</th>
# <th class="size-chart-header" id="column15" scope="column">9.5</th>
# <th class="size-chart-header" id="column16" scope="column">10</th>
# <th class="size-chart-header" id="column17" scope="column">10.5</th>
# <th class="size-chart-header" id="column18" scope="column">11</th>
# <th class="size-chart-header" id="column19" scope="column">11.5</th>
# <th class="size-chart-header" id="column20" scope="column">12</th>
# <th class="size-chart-header" id="column21" scope="column">12.5</th>
# <th class="size-chart-header" id="column22" scope="column">13</th>
# <th class="size-chart-header" id="column23" scope="column">13.5</th>
# <th class="size-chart-header" id="column24" scope="column">14</th>
# <th class="size-chart-header" id="column25" scope="column">15</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="size-chart-header" id="row0" scope="row">U.S. Men's</th></tr></tbody></table></div></div></div></div></div></div></div></div>, <div id="browserUpgrade"></div>, <div class="inner-wrap">
# <header class="site-header" id="headerWrapper" role="banner">
# <div class="unav-wrap" data-ui="unav-container" id="js-unav-wrap">
# <nav aria-label="primary" class="unav" id="js-unav">
# <ul class="items">
# <li class="item skip-link--accessibility unav-skip-link sr-only" data-skip-show="accessibility-statement">
# <a data-skip-link="accessibility-statement" href="https://www.rei.com/accessibility">
#           REI Accessibility Statement
#         </a>
# </li>
# <li class="item skip-link--main-content unav-skip-link sr-only" data-skip-show="content">
# <a data-skip-link="content" href="#page-content">
#           Skip to main content
#         </a>
# </li>
# <li class="item skip-link--secondary-nav unav-skip-link sr-only" data-skip-show="secondary-nav">
# <a data-skip-link="secondary-nav" href="#secondary-nav">Skip to Shop REI categories</a>
# </li>
# <li class="item active">
# <a aria-label="Current Page: Shop REI" data-analytics-id="universal_nav:shop rei" data-ui="unav-link" href="/">Shop REI</a>
# </li>
# <li class="item">
# <a data-analytics-id="universal_nav:rei garage" data-ui="unav-link" href="/rei-garage">REI Outlet</a>
# </li>
# <li class="item">
# <a data-analytics-id="universal_nav:used gear" data-ui="unav-link" href="/used">Used Gear</a>
# </li>
# <li class="item">
# <a data-analytics-id="universal_nav:rei adventures" data-ui="unav-link" href="/adventures">REI Adventures</a>
# </li>
# <li class="item">
# <a data-analytics-id="universal_nav:classes &amp; events" data-ui="unav-link" href="/events">Classes &amp; Events</a>
# </li>
# <li class="item">
# <a data-analytics-id="universal_nav:expert advice" data-ui="unav-link" href="/learn/expert-advice">Expert Advice</a>
# </li>
# <li class="item">
# <a data-analytics-id="universal_nav:co-op journal" data-ui="unav-link" href="/blog">Co-op Journal</a>
# </li>
# <li class="item">
# <a data-analytics-id="universal_nav:conversations" data-ui="unav-link" href="https://conversations.rei.com">Conversations</a>
# </li>
# <li class="item membership-unav">
# <span>•</span>
# <a data-analytics-id="universal_nav:membership" data-ui="unav-link" href="/membership/benefits">Membership</a>
# </li>
# </ul>
# </nav>
# </div>
# <style>
#     #js-unav li.item.membership-unav{
#         display: inline-flex;
#     }
#     #js-unav .item.membership-unav span{
#         align-self: center;
#         color: #fff;
#     }
# </style><script>
#     window.useNewMinicart = true;
#     </script>
# <script data-client-store="analytics" type="application/json">{"useTealiumForMarin":"false","useTealiumSync":"true","isRedesign":"true","siteCatalystEnabled":"false","testAndTargetLibraryUrl":"\/\/satchel.rei.com\/packages\/adobe-target\/at-v2.2.0.js","testAndTargetEnabled":"true","useAdobeTargetLibraryUrl":null,"slothEnabled":"true","useClientContextService":"true","targetPerformanceMetricsEnabled":"true","tealiumSyncLibraryURL":"\/\/satchel.rei.com\/packages\/tealium\/utag.sync-4.4.0.js","tealiumEnabled":"true","tealiumLibraryURL":"\/\/tags.tiqcdn.com\/utag\/rei\/main\/prod\/utag.js"}</script><script data-client-store="app-props" type="application/json">{"useEmailAcq":"true","performanceDeferRR":"true","asyncBannerSourceURL":"https:\/\/satchel.rei.com\/media\/global\/async-banner.html","emailAcqSitekey":"6LdGCh8UAAAAAI78ftxgsyMBmlXMQMnuLSpNI8vI","useHandlebars":"true","useAsyncBanner":"false","performanceDeferTealium":"true"}</script><script data-client-store="emailAcq" type="application/json">{"supressEmailAcq":null}</script><script data-client-store="minicart-messages" type="application/json">{"minicartShippingMessagePrimary":"FREE SHIPPING","cartRelPath":"\/ShoppingCart","minicartShippingMessageSecondary":"<a href=\"\/terms\/free-shipping\">With $50 minimum purchase.<\/a>","checkoutRelPath":"\/CheckoutLoginView","loginRelPath":"\/YourAccountLoginView"}</script><div class="site-header-inner container" data-ui="site-header"> <div class="site-header-masthead"> <div class="site-header-logo pull-left"> <div class="site-header-logo-inner"> <a data-analytics-id="rei_utilitylinks_logo" data-ui="site-header-logo" href="/"> <img alt="Go to REI.com Home Page" class="svg-logo" src="//satchel.rei.com/media/img/header/rei-co-op-logo-white.svg"/> </a> </div></div> <div class="site-header-body"> <div class="header-actions"> <div class="header-actions-user pull-right"> <ul class="masthead-actions"> <li class="cart"> <a class="js-cart-action wrapper-nav-link" data-analytics-id="rei_utilitylinks_cart" data-ui="shopping-cart-link" href="/ShoppingCart"> <span class="sr-only">Cart</span> <i class="empty js-cart-icon-empty"></i> <i class="full hidden js-cart-icon-full"></i> <div class="count js-cart-count-wrapper"> <span class="js-cart-count" data-ui="cart-item-count"></span> </div> </a> </li> <li class="burger"> <button class="js-burger" data-analytics-id="rei_utilitylinks_menu" data-state="close" data-ui="site-header-action-menu" type="button"> <span class="sr-only">Menu</span><i></i> </button> </li> </ul> </div> <div class="header-actions-search"> <div class="site-header-search" data-ui="submit-search-term"> <form action="/search" class="form-inline icon-label" method="GET" name="psearch" role="search"> <div class="form-group"> <div class="input-group"> <input aria-labelledby="searchbutton" autocorrect="off" class="search-box form-control form-control-input" data-ui="site-header-site-search-input" id="inputGroup" maxlength="70" name="q" placeholder="Search for great gear &amp; clothing" title="search input field" type="search"/> <span class="input-group-btn"> <button class="btn search-button" data-ui="search-button" id="searchbutton" title="Search"> <span class="sr-only">Search</span> <span aria-hidden="true" class="icon icon-rei-search pull-left"></span> </button> </span> </div> </div> </form> </div> </div> </div> <hr class="hidden-sm hidden-xs"/> <div class="header-nav-container"> <nav data-ui="site-navigation" role="navigation"> <ul class="actions"> <li class="sign-in"> <a aria-controls="sign-in-container" aria-expanded="false" class="wrapper-nav-link js-sign-in" data-ui="login-module-greeting" href="/YourAccountInfoInView" rel="nofollow"> <span class="sign-in-txt">Sign in</span><span class="my-account-txt">My account</span><i></i> </a> </li> <li class="sign-in-dropdown" data-ui="login-module"> <div id="sign-in-container"> <div class="mtns"> <svg aria-hidden="true" class="twin-peaks-svg-container__twin-peaks-svg" height="19" version="1.0" ...
# <div id="nav-promo">
# <style>
# #nav-promo-4f157df3-aa2e-4d7a-a4c5-a1d1129a93b8{
# ...
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M21 5a1 1 0 011 1v12a1 1 0 01-1 1H3a1 1 0 01-1-1V6a1 1 0 011-1h18zm-1 3.536l-7.483 4.32a1 1 0 01-1.017.01L4 8.536V17h16V8.536zM18.658 7H5.34L12 10.845 18.658 7z"></path></svg>
# <span>Sign up</span>
# </button>
# <!-- /Submit Button -->
# <!-- Cancel Button -->
# <button class="btn btn-sm btn-no-defaults close-btn no-thanks-btn btn-default" data-dismiss="modal" data-ui="modalCloseButton" type="button">
#                     No thanks
#                   </button>
# <!-- /Cancel Button -->
# <div class="g-recaptcha" data-callback="emailAcqCaptchaCallback" data-sitekey="6LdGCh8UAAAAAI78ftxgsyMBmlXMQMnuLSpNI8vI" data-size="invisible" id="recaptcha"></div>
# <a class="link-body text-small privacy-policy" href="https://help.rei.com/app/answers/detail/a_id/50" target="_blank">REI Co-op Privacy Policy</a>
# </div>
# <!-- /Captcha Group -->
# </fieldset>
# </form>
# <!-- /Email Input Form -->
# </div>
# <!-- /Sign-Up Form Container -->
# </div>
# <!-- /Modal Body Content -->
# </div>
# <!-- /Modal Body Container -->
# </div>
# <!-- Modal Main Content -->
# </div>, <div class="modal-content">
# <header class="modal-header">
# <button aria-label="Close" class="close close-btn" data-ui="modalCloseButton">
# <span class="close-text">Close</span>
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.415 12.006l5.295-5.292a1 1 0 00-1.414-1.415L12 10.591 6.71 5.296A1 1 0 005.295 6.71l5.292 5.295-5.295 5.292a1 1 0 101.414 1.414l5.295-5.292 5.292 5.295a1 1 0 001.414-1.414l-5.292-5.294z"></path></svg>
# </button>
# </header>
# <h3 class="modal-title">Sign up for REI <span style="display:inline-block">Co-op</span> emails</h3>
# <div class="signup active view">
# <p class="modal-subheading">
#          Stay updated on the latest news, deals &amp; more.
#         </p>
# </div>
# <div class="confirm view">
# <p class="modal-subheading">
#           Success! Check your inbox for more perks. We’ll send you a few emails every week. <br/><br/>You can unsubscribe from REI Co-op emails at any time.
#         </p>
# <p class="unsub-message">
# <a class="link-body text-small privacy-policy" href="https://help.rei.com/app/answers/detail/a_id/50" target="_blank">REI Co-op Privacy Policy</a></p>
# </div>
# <div class="modal-body">
# <!-- Modal Body Content -->
# <div class="modal-body-content" data-ui="modalText">
# <!-- Sign-Up Form Container -->
# <div class="view signup active">
# <!-- Email Input Form -->
# <form action="/gearmail/new/signup" data-ui="email-acquisition-form" id="emailAcqForm" method="POST" novalidate="" role="form">
# <fieldset>
# <!-- Internal Elements -->
# <legend class="sr-only"> Email Opt-in </legend>
# <input name="sourceCode" type="hidden" value="00100100100420170501"/>
# <!-- /Internal Elements -->
# <!-- Form Group -->
# <div class="form-group">
# <div class="label-group">
# <label class="modal-label" for="emailAcqInputEmail">
# <span>Email (Required)</span>
# </label>
# </div>
# <div class="input-wrap">
# <input aria-required="true" autocapitalize="off" class="form-control" data-ui="input-email" id="emailAcqInputEmail" name="emailAddress" placeholder="Enter your email address" spellcheck="false" type="email">
# <svg class="error-icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2c5.523 0 10 4.477 10 10s-4.477 10-10 10S2 17.523 2 12 6.477 2 12 2zm0 13.5a1.25 1.25 0 100 2.5 1.25 1.25 0 000-2.5zm.22-9.5h-.44a1 1 0 00-.996.913l-.004.116.191 6.5a1 1 0 00.886.965l.114.006h.058a1 1 0 00.99-.857l.01-.114.19-6.5A1 1 0 0012.22 6z"></path></svg>
# </input></div>
# <div class="error-message" id="email-error-message">Please use yourname@example.com format</div>
# </div>
# <!-- /Form Group -->
# <!-- Captcha Group -->
# <div class="captcha-group">
# <!-- Submit Button -->
# <button class="btn btn-sm btn-contrast btn-primary" data-badge="inline" data-ui="btn-signup" id="emailAcqSubmit" type="submit">
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M21 5a1 1 0 011 1v12a1 1 0 01-1 1H3a1 1 0 01-1-1V6a1 1 0 011-1h18zm-1 3.536l-7.483 4.32a1 1 0 01-1.017.01L4 8.536V17h16V8.536zM18.658 7H5.34L12 10.845 18.658 7z"></path></svg>
# <span>Sign up</span>
# </button>
# <!-- /Submit Button -->
# <!-- Cancel Button -->
# <button class="btn btn-sm btn-no-defaults close-btn no-thanks-btn btn-default" data-dismiss="modal" data-ui="modalCloseButton" type="button">
#                     No thanks
#                   </button>
# <!-- /Cancel Button -->
# <div class="g-recaptcha" data-callback="emailAcqCaptchaCallback" data-sitekey="6LdGCh8UAAAAAI78ftxgsyMBmlXMQMnuLSpNI8vI" data-size="invisible" id="recaptcha"></div>
# <a class="link-body text-small privacy-policy" href="https://help.rei.com/app/answers/detail/a_id/50" target="_blank">REI Co-op Privacy Policy</a>
# </div>
# <!-- /Captcha Group -->
# </fieldset>
# </form>
# <!-- /Email Input Form -->
# </div>
# <!-- /Sign-Up Form Container -->
# </div>
# <!-- /Modal Body Content -->
# </div>
# <!-- /Modal Body Container -->
# </div>, <div class="signup active view">
# <p class="modal-subheading">
#          Stay updated on the latest news, deals &amp; more.
#         </p>
# </div>, <div class="confirm view">
# <p class="modal-subheading">
#           Success! Check your inbox for more perks. We’ll send you a few emails every week. <br/><br/>You can unsubscribe from REI Co-op emails at any time.
#         </p>
# <p class="unsub-message">
# <a class="link-body text-small privacy-policy" href="https://help.rei.com/app/answers/detail/a_id/50" target="_blank">REI Co-op Privacy Policy</a></p>
# </div>, <div class="modal-body">
# <!-- Modal Body Content -->
# <div class="modal-body-content" data-ui="modalText">
# <!-- Sign-Up Form Container -->
# <div class="view signup active">
# <!-- Email Input Form -->
# <form action="/gearmail/new/signup" data-ui="email-acquisition-form" id="emailAcqForm" method="POST" novalidate="" role="form">
# <fieldset>
# <!-- Internal Elements -->
# <legend class="sr-only"> Email Opt-in </legend>
# <input name="sourceCode" type="hidden" value="00100100100420170501"/>
# <!-- /Internal Elements -->
# <!-- Form Group -->
# <div class="form-group">
# <div class="label-group">
# <label class="modal-label" for="emailAcqInputEmail">
# <span>Email (Required)</span>
# </label>
# </div>
# <div class="input-wrap">
# <input aria-required="true" autocapitalize="off" class="form-control" data-ui="input-email" id="emailAcqInputEmail" name="emailAddress" placeholder="Enter your email address" spellcheck="false" type="email">
# <svg class="error-icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2c5.523 0 10 4.477 10 10s-4.477 10-10 10S2 17.523 2 12 6.477 2 12 2zm0 13.5a1.25 1.25 0 100 2.5 1.25 1.25 0 000-2.5zm.22-9.5h-.44a1 1 0 00-.996.913l-.004.116.191 6.5a1 1 0 00.886.965l.114.006h.058a1 1 0 00.99-.857l.01-.114.19-6.5A1 1 0 0012.22 6z"></path></svg>
# </input></div>
# <div class="error-message" id="email-error-message">Please use yourname@example.com format</div>
# </div>
# <!-- /Form Group -->
# <!-- Captcha Group -->
# <div class="captcha-group">
# <!-- Submit Button -->
# <button class="btn btn-sm btn-contrast btn-primary" data-badge="inline" data-ui="btn-signup" id="emailAcqSubmit" type="submit">
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M21 5a1 1 0 011 1v12a1 1 0 01-1 1H3a1 1 0 01-1-1V6a1 1 0 011-1h18zm-1 3.536l-7.483 4.32a1 1 0 01-1.017.01L4 8.536V17h16V8.536zM18.658 7H5.34L12 10.845 18.658 7z"></path></svg>
# <span>Sign up</span>
# </button>
# <!-- /Submit Button -->
# <!-- Cancel Button -->
# <button class="btn btn-sm btn-no-defaults close-btn no-thanks-btn btn-default" data-dismiss="modal" data-ui="modalCloseButton" type="button">
#                     No thanks
#                   </button>
# <!-- /Cancel Button -->
# <div class="g-recaptcha" data-callback="emailAcqCaptchaCallback" data-sitekey="6LdGCh8UAAAAAI78ftxgsyMBmlXMQMnuLSpNI8vI" data-size="invisible" id="recaptcha"></div>
# <a class="link-body text-small privacy-policy" href="https://help.rei.com/app/answers/detail/a_id/50" target="_blank">REI Co-op Privacy Policy</a>
# </div>
# <!-- /Captcha Group -->
# </fieldset>
# </form>
# <!-- /Email Input Form -->
# </div>
# <!-- /Sign-Up Form Container -->
# </div>
# <!-- /Modal Body Content -->
# </div>, <div class="modal-body-content" data-ui="modalText">
# <!-- Sign-Up Form Container -->
# <div class="view signup active">
# <!-- Email Input Form -->
# <form action="/gearmail/new/signup" data-ui="email-acquisition-form" id="emailAcqForm" method="POST" novalidate="" role="form">
# <fieldset>
# <!-- Internal Elements -->
# <legend class="sr-only"> Email Opt-in </legend>
# <input name="sourceCode" type="hidden" value="00100100100420170501"/>
# <!-- /Internal Elements -->
# <!-- Form Group -->
# <div class="form-group">
# <div class="label-group">
# <label class="modal-label" for="emailAcqInputEmail">
# <span>Email (Required)</span>
# </label>
# </div>
# <div class="input-wrap">
# <input aria-required="true" autocapitalize="off" class="form-control" data-ui="input-email" id="emailAcqInputEmail" name="emailAddress" placeholder="Enter your email address" spellcheck="false" type="email">
# <svg class="error-icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2c5.523 0 10 4.477 10 10s-4.477 10-10 10S2 17.523 2 12 6.477 2 12 2zm0 13.5a1.25 1.25 0 100 2.5 1.25 1.25 0 000-2.5zm.22-9.5h-.44a1 1 0 00-.996.913l-.004.116.191 6.5a1 1 0 00.886.965l.114.006h.058a1 1 0 00.99-.857l.01-.114.19-6.5A1 1 0 0012.22 6z"></path></svg>
# </input></div>
# <div class="error-message" id="email-error-message">Please use yourname@example.com format</div>
# </div>
# <!-- /Form Group -->
# <!-- Captcha Group -->
# <div class="captcha-group">
# <!-- Submit Button -->
# <button class="btn btn-sm btn-contrast btn-primary" data-badge="inline" data-ui="btn-signup" id="emailAcqSubmit" type="submit">
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M21 5a1 1 0 011 1v12a1 1 0 01-1 1H3a1 1 0 01-1-1V6a1 1 0 011-1h18zm-1 3.536l-7.483 4.32a1 1 0 01-1.017.01L4 8.536V17h16V8.536zM18.658 7H5.34L12 10.845 18.658 7z"></path></svg>
# <span>Sign up</span>
# </button>
# <!-- /Submit Button -->
# <!-- Cancel Button -->
# <button class="btn btn-sm btn-no-defaults close-btn no-thanks-btn btn-default" data-dismiss="modal" data-ui="modalCloseButton" type="button">
#                     No thanks
#                   </button>
# <!-- /Cancel Button -->
# <div class="g-recaptcha" data-callback="emailAcqCaptchaCallback" data-sitekey="6LdGCh8UAAAAAI78ftxgsyMBmlXMQMnuLSpNI8vI" data-size="invisible" id="recaptcha"></div>
# <a class="link-body text-small privacy-policy" href="https://help.rei.com/app/answers/detail/a_id/50" target="_blank">REI Co-op Privacy Policy</a>
# </div>
# <!-- /Captcha Group -->
# </fieldset>
# </form>
# <!-- /Email Input Form -->
# </div>
# <!-- /Sign-Up Form Container -->
# </div>, <div class="view signup active">
# <!-- Email Input Form -->
# <form action="/gearmail/new/signup" data-ui="email-acquisition-form" id="emailAcqForm" method="POST" novalidate="" role="form">
# <fieldset>
# <!-- Internal Elements -->
# <legend class="sr-only"> Email Opt-in </legend>
# <input name="sourceCode" type="hidden" value="00100100100420170501"/>
# <!-- /Internal Elements -->
# <!-- Form Group -->
# <div class="form-group">
# <div class="label-group">
# <label class="modal-label" for="emailAcqInputEmail">
# <span>Email (Required)</span>
# </label>
# </div>
# <div class="input-wrap">
# <input aria-required="true" autocapitalize="off" class="form-control" data-ui="input-email" id="emailAcqInputEmail" name="emailAddress" placeholder="Enter your email address" spellcheck="false" type="email">
# <svg class="error-icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2c5.523 0 10 4.477 10 10s-4.477 10-10 10S2 17.523 2 12 6.477 2 12 2zm0 13.5a1.25 1.25 0 100 2.5 1.25 1.25 0 000-2.5zm.22-9.5h-.44a1 1 0 00-.996.913l-.004.116.191 6.5a1 1 0 00.886.965l.114.006h.058a1 1 0 00.99-.857l.01-.114.19-6.5A1 1 0 0012.22 6z"></path></svg>
# </input></div>
# <div class="error-message" id="email-error-message">Please use yourname@example.com format</div>
# </div>
# <!-- /Form Group -->
# <!-- Captcha Group -->
# <div class="captcha-group">
# <!-- Submit Button -->
# <button class="btn btn-sm btn-contrast btn-primary" data-badge="inline" data-ui="btn-signup" id="emailAcqSubmit" type="submit">
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M21 5a1 1 0 011 1v12a1 1 0 01-1 1H3a1 1 0 01-1-1V6a1 1 0 011-1h18zm-1 3.536l-7.483 4.32a1 1 0 01-1.017.01L4 8.536V17h16V8.536zM18.658 7H5.34L12 10.845 18.658 7z"></path></svg>
# <span>Sign up</span>
# </button>
# <!-- /Submit Button -->
# <!-- Cancel Button -->
# <button class="btn btn-sm btn-no-defaults close-btn no-thanks-btn btn-default" data-dismiss="modal" data-ui="modalCloseButton" type="button">
#                     No thanks
#                   </button>
# <!-- /Cancel Button -->
# <div class="g-recaptcha" data-callback="emailAcqCaptchaCallback" data-sitekey="6LdGCh8UAAAAAI78ftxgsyMBmlXMQMnuLSpNI8vI" data-size="invisible" id="recaptcha"></div>
# <a class="link-body text-small privacy-policy" href="https://help.rei.com/app/answers/detail/a_id/50" target="_blank">REI Co-op Privacy Policy</a>
# </div>
# <!-- /Captcha Group -->
# </fieldset>
# </form>
# <!-- /Email Input Form -->
# </div>, <div class="form-group">
# <div class="label-group">
# <label class="modal-label" for="emailAcqInputEmail">
# <span>Email (Required)</span>
# </label>
# </div>
# <div class="input-wrap">
# <input aria-required="true" autocapitalize="off" class="form-control" data-ui="input-email" id="emailAcqInputEmail" name="emailAddress" placeholder="Enter your email address" spellcheck="false" type="email">
# <svg class="error-icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2c5.523 0 10 4.477 10 10s-4.477 10-10 10S2 17.523 2 12 6.477 2 12 2zm0 13.5a1.25 1.25 0 100 2.5 1.25 1.25 0 000-2.5zm.22-9.5h-.44a1 1 0 00-.996.913l-.004.116.191 6.5a1 1 0 00.886.965l.114.006h.058a1 1 0 00.99-.857l.01-.114.19-6.5A1 1 0 0012.22 6z"></path></svg>
# </input></div>
# <div class="error-message" id="email-error-message">Please use yourname@example.com format</div>
# </div>, <div class="label-group">
# <label class="modal-label" for="emailAcqInputEmail">
# <span>Email (Required)</span>
# </label>
# </div>, <div class="input-wrap">
# <input aria-required="true" autocapitalize="off" class="form-control" data-ui="input-email" id="emailAcqInputEmail" name="emailAddress" placeholder="Enter your email address" spellcheck="false" type="email">
# <svg class="error-icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12 2c5.523 0 10 4.477 10 10s-4.477 10-10 10S2 17.523 2 12 6.477 2 12 2zm0 13.5a1.25 1.25 0 100 2.5 1.25 1.25 0 000-2.5zm.22-9.5h-.44a1 1 0 00-.996.913l-.004.116.191 6.5a1 1 0 00.886.965l.114.006h.058a1 1 0 00.99-.857l.01-.114.19-6.5A1 1 0 0012.22 6z"></path></svg>
# </input></div>, <div class="error-message" id="email-error-message">Please use yourname@example.com format</div>, <div class="captcha-group">
# <!-- Submit Button -->
# <button class="btn btn-sm btn-contrast btn-primary" data-badge="inline" data-ui="btn-signup" id="emailAcqSubmit" type="submit">
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M21 5a1 1 0 011 1v12a1 1 0 01-1 1H3a1 1 0 01-1-1V6a1 1 0 011-1h18zm-1 3.536l-7.483 4.32a1 1 0 01-1.017.01L4 8.536V17h16V8.536zM18.658 7H5.34L12 10.845 18.658 7z"></path></svg>
# <span>Sign up</span>
# </button>
# <!-- /Submit Button -->
# <!-- Cancel Button -->
# <button class="btn btn-sm btn-no-defaults close-btn no-thanks-btn btn-default" data-dismiss="modal" data-ui="modalCloseButton" type="button">
#                     No thanks
#                   </button>
# <!-- /Cancel Button -->
# <div class="g-recaptcha" data-callback="emailAcqCaptchaCallback" data-sitekey="6LdGCh8UAAAAAI78ftxgsyMBmlXMQMnuLSpNI8vI" data-size="invisible" id="recaptcha"></div>
# <a class="link-body text-small privacy-policy" href="https://help.rei.com/app/answers/detail/a_id/50" target="_blank">REI Co-op Privacy Policy</a>
# </div>, <div class="g-recaptcha" data-callback="emailAcqCaptchaCallback" data-sitekey="6LdGCh8UAAAAAI78ftxgsyMBmlXMQMnuLSpNI8vI" data-size="invisible" id="recaptcha"></div>]
# None

# %%
# Let's look at the first 10 to see if the null values mapped properly
pd.set_option('display.max_rows', 10)
shoes_df
# Out:
#                      Shoe_Name   Shoe_Company Current_Price Original_Price  \
# 0     Rogue VCS Climbing Shoes       Five Ten        $39.93        $100.00
# 1       Quantum Climbing Shoes       Five Ten        $69.93        $185.00
# 2   Instinct VS Climbing Shoes         Scarpa       $141.69        $189.00
# 3      Momentum Climbing Shoes  Black Diamond        $46.73         $94.95
# 4        Finale Climbing Shoes    La Sportiva       $109.00        $109.00
# ..                         ...            ...           ...            ...
# 63     Momentum Climbing Shoes  Black Diamond        $59.93         $94.95
# 64       Aspect Climbing Shoes  Black Diamond       $149.95        $149.95
# 65       Oxygym Climbing Shoes    La Sportiva        $99.00         $99.00
# 66   Mythos Eco Climbing Shoes    La Sportiva       $145.00        $145.00
# 67      Force V Climbing Shoes         Scarpa       $104.19        $139.00
#
#    Discount                                       Product_Link        Rating  \
# 0      True  rei.com/product/170687/five-ten-rogue-vcs-clim...  4.5 out of 5
# 1      True  rei.com/product/103459/five-ten-quantum-climbi...  4.8 out of 5
# 2      True  rei.com/product/849257/scarpa-instinct-vs-clim...  4.5 out of 5
# 3      True  rei.com/rei-garage/product/174923/black-diamon...  4.5 out of 5
# 4     False  rei.com/product/896622/la-sportiva-finale-clim...  4.4 out of 5
# ..      ...                                                ...           ...
# 63     True  rei.com/product/126525/black-diamond-momentum-...  4.5 out of 5
# 64    False  rei.com/product/122575/black-diamond-aspect-cl...  4.3 out of 5
# 65    False  rei.com/product/112199/la-sportiva-oxygym-clim...  3.4 out of 5
# 66    False  rei.com/product/112198/la-sportiva-mythos-eco-...  4.6 out of 5
# 67     True  rei.com/product/110330/scarpa-force-v-climbing...  3.8 out of 5
#
#    Rating_Count
# 0             6
# 1             5
# 2            23
# 3             4
# 4            72
# ..          ...
# 63            4
# 64           65
# 65           24
# 66           14
# 67           30
#
# [68 rows x 8 columns]

# %% [markdown]
# ### Step 2: Connect to an SQL database
#
# Here, I'm using the sqlalchemy package's engine function to establish a connection to my postgresql database where I create an sql table from my existing pandas dataframe.

# %%
# Create engine connected to sql database
engine = create_engine('postgresql://postgres:postgres@localhost:5432/Climbing_Shoes', echo=False)

# %%
# Convert pandas dataframe to SQL database
shoes_df.to_sql('shoes', engine, if_exists='replace')

# %% [markdown]
# ### Step 3: Data Cleaning
#
# In order to perform data analysis, we need to decide what kind of questions we want to ask about the climbing shoes with the data that we have. Let's start with some basic questions, and utilize visuals to help us answer our questions.
#
# But first thing's first, let's clean the data enough to perform some comparisons and groupings.

# %%
# Make a copy so we don't alter the original dataframe
clean_df = shoes_df.copy()

# %%
# Strip '$' from the Price columns
clean_df['Current_Price'] = clean_df['Current_Price'].str.replace('$', '')
clean_df['Original_Price'] = clean_df['Original_Price'].str.replace('$', '')

# %% [markdown]
# At this point, I wanted to convert the `Current_Price` and `Original_Price` columns to float type at the same time as stripping the '\\$' symbol, but I encountered edge cases of price ranges. For example, the Origin Climbing Shoes from Scarpa has a price range of \\$71.19 - \\$75.93, which can't be converted to a float even after removing the \\$ symbols. I was able to bypass this problem by split the column value by the '-' symbol, so price ranges would have two values in the list and single prices would just be the lone value in the list. Then, I simply replaced the list value with its average.

# %%
# Define a function I can apply to the Price Series to get average of a list
def avg_lst(lst):
    lst = list(map(float, lst)) 
    return sum(lst) / len(lst)

# %%
# Split the price value and apply the avg_lst function
clean_df['Current_Price'] = clean_df['Current_Price'].str.split("-", n = 1, expand = False)
clean_df['Current_Price'] = clean_df['Current_Price'].apply(avg_lst)
clean_df['Original_Price'] = clean_df['Original_Price'].str.split("-", n = 1, expand = False)
clean_df['Original_Price'] = clean_df['Original_Price'].apply(avg_lst)
clean_df.head()
# Out:
#                     Shoe_Name Shoe_Company  Current_Price  Original_Price  \
# 0    Rogue VCS Climbing Shoes     Five Ten          39.93           100.0
# 1      Quantum Climbing Shoes     Five Ten          69.93           185.0
# 2       Finale Climbing Shoes  La Sportiva         109.00           109.0
# 3       Origin Climbing Shoes       Scarpa          74.19            99.0
# 4  Instinct VS Climbing Shoes       Scarpa         141.69           189.0
#
#   Discount        Rating Rating_Count
# 0     True  4.5 out of 5            6
# 1     True  4.8 out of 5            5
# 2    False  4.4 out of 5           72
# 3     True           NaN            0
# 4     True  4.5 out of 5           23

# %%
clean_df['Rating'] = clean_df['Rating'].str.split().str[0].astype(float)
clean_df['Rating_Count'] = clean_df['Rating_Count'].astype(int)
clean_df.head()
# Out:
#                     Shoe_Name Shoe_Company  Current_Price  Original_Price  \
# 0    Rogue VCS Climbing Shoes     Five Ten          39.93           100.0
# 1      Quantum Climbing Shoes     Five Ten          69.93           185.0
# 2       Finale Climbing Shoes  La Sportiva         109.00           109.0
# 3       Origin Climbing Shoes       Scarpa          74.19            99.0
# 4  Instinct VS Climbing Shoes       Scarpa         141.69           189.0
#
#   Discount  Rating  Rating_Count
# 0     True     4.5             6
# 1     True     4.8             5
# 2    False     4.4            72
# 3     True     NaN             0
# 4     True     4.5            23

# %% [markdown]
# ### Step 4: Exploratory Data Analysis!
#
# Yay! Now that the boring data cleaning section is (mostly) over, let's think about some questions we're interested in.
#
# - Which shoe brand is the most popular?
# - Which shoe has the highest rating on average?
# - Which shoe is the most popular?
# - What is the most expensive shoe?
# - Which shoe brand charges the most on average?
# - Do discounted shoes have higher or lower ratings?

# %%
# Use the groupby function to add the total Rating_Count of each shoe brand
sum_by_brand = clean_df.groupby('Shoe_Company').sum().sort_values('Rating_Count', ascending=False)
plt.title('Rating Counts by Brand')
plt.barh(sum_by_brand['Rating_Count'].index, sum_by_brand['Rating_Count'])
# Out:
# <BarContainer object of 9 artists>

# %%
# Use value counts to see how many shoe listings there are by each brand
counts = clean_df['Shoe_Company'].value_counts().rename('Shoe_Counts')
plt.title('Number of Shoe Listings by Brand')
plt.barh(counts.index, counts)
# Out:
# <BarContainer object of 9 artists>

# %%
# Use pandas concat function to join the two series together keyed on the index
ratings_per_shoe = pd.concat([counts, sum_by_brand['Rating_Count']], axis=1)
ratings_per_shoe['Ratings_per_shoe'] = ratings_per_shoe['Rating_Count'] / ratings_per_shoe['Shoe_Counts']
plt.title('Average Ratings per Shoe by Brand')
plt.barh(ratings_per_shoe.index, ratings_per_shoe['Ratings_per_shoe'])
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# Here, we can see that La Sportiva has significantly more ratings than other brands and also has the most ratings per shoe listing. From this, we can identify that La Sportiva either sells many more products than their competitors which increases the number of customer reviews, or La Sportiva sells the same amount as other brands but their customers are more inclined to leave reviews on their products. This is solid evidence that La Sportiva is the most popular brand.

# %%
# Groupby mean to identify the average ratings for each company
avg_by_brand = clean_df.groupby('Shoe_Company').mean().sort_values('Rating', ascending = False)

display(avg_by_brand)

# Create horizontal bar plot with labels
fig, ax = plt.subplots()
plt.title('Average Rating by Brand')
plt.barh(avg_by_brand.index, avg_by_brand['Rating'])

for i, v in enumerate(avg_by_brand['Rating']):
    ax.text(v + 0.1, i - 0.11, str(('%.2f' %v)), color='black', fontweight='bold')
# Out:
#                Current_Price  Original_Price    Rating  Rating_Count
# Shoe_Company
# Metolius           14.890000       19.950000  4.800000      5.000000
# Butora            143.540000      143.540000  4.700000      2.800000
# La Sportiva       161.000000      161.000000  4.491667     29.461538
# TENAYA            144.945000      157.462500  4.450000      5.000000
# evolv             138.333333      138.333333  4.400000     11.000000
# Scarpa            117.637500      156.666667  4.310000     14.583333
# Five Ten           98.274286      141.071429  4.050000      8.214286
# Black Diamond      89.581111      131.061111  3.950000     18.888889
# So iLL            117.074286      141.857143  3.900000     18.285714

# %% [markdown]
# With this horizontal bar graph, we can see that Metolius and Butora have relatively higher average ratings than the other brands. However in the dataframe above it, we see that they have 5 and 2.8 average number of ratings total in comparison to other brands like La Sportiva that boast 29.46 average ratings per shoe. With small sample sizes (low rating counts), it's always hard to determine the validity of the ratings because the rating is determined by such few individuals.
#
# Because of this, I think we can say that Butora, Metolius, and even TENAYA shoes are a little riskier to buy with potentially great shoes, but for products with more reliable ratings, La Sportiva, evolv, and Scarpa are your go to.
#
# **We also didn't account for the shoes with 0 rating counts. Further analysis could involve imputation or additional webscraping from other websites.**

# %%
# Sort shoes by rating count to see which shoes have the most ratings
popular_shoes = clean_df.sort_values('Rating_Count', ascending = False).head()

# Create pie chart of the top 5 climbing shoes with highest rating counts
explode = (0.1, 0, 0, 0, 0)
fig1, ax1 = plt.subplots()
ax1.pie(popular_shoes['Rating_Count'], explode=explode, labels=popular_shoes['Shoe_Name'], autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# Since we don't have the exact number of purchases of each shoe, the only way we can determine the popularity of each shoe is by its rating count. By this standard, the TC Pro Climbing Shoes were the most popular.

# %%
# Sort shoes by original and current price to identify the most expensive shoes
orig_price = clean_df.sort_values('Original_Price', ascending = False)
display(orig_price.head())

shoes_price = clean_df.sort_values('Current_Price', ascending = False)
display(shoes_price.head())
# Out:
#                          Shoe_Name Shoe_Company  Current_Price  \
# 49        Furia Air Climbing Shoes       Scarpa         149.19
# 25  Maestro Mid Eco Climbing Shoes       Scarpa         149.19
# 24           Genius Climbing Shoes  La Sportiva         195.00
# 13      Katana Lace Climbing Shoes  La Sportiva         195.00
# 59          Mundaka Climbing Shoes       TENAYA         194.95
#
#     Original_Price Discount  Rating  Rating_Count
# 49          199.00     True     5.0             1
# 25          199.00     True     3.7             3
# 24          195.00    False     4.4            16
# 13          195.00    False     4.7            20
# 59          194.95    False     4.7            12
#                      Shoe_Name Shoe_Company  Current_Price  Original_Price  \
# 13  Katana Lace Climbing Shoes  La Sportiva         195.00          195.00
# 24       Genius Climbing Shoes  La Sportiva         195.00          195.00
# 59      Mundaka Climbing Shoes       TENAYA         194.95          194.95
# 10       TC Pro Climbing Shoes  La Sportiva         190.00          190.00
# 43       Theory Climbing Shoes  La Sportiva         190.00          190.00
#
#    Discount  Rating  Rating_Count
# 13    False     4.7            20
# 24    False     4.4            16
# 59    False     4.7            12
# 10    False     4.8            74
# 43    False     NaN             0

# %% [markdown]
# Here, we can see Scarpa offers the two most expensive shoes, both priced at \\$199.00. However, these two shoes are currently on sale, making them significantly cheaper. 4 of the 5 currently most expensive shoes are of La Sportiva brand, and they are relatively well-rated, excluding the Theory Climbing Shoes which haven't been rated yet.

# %%
discounted = clean_df.groupby('Discount').mean()
discounted
# Out:
#           Current_Price  Original_Price    Rating  Rating_Count
# Discount
# False        148.400000      148.400000  4.348387     17.944444
# True          90.350312      142.520312  4.143333     12.406250

# %% [markdown]
# From this dataframe, we can conclude that discounted shoes typically have lower and less ratings. While it's not a statistically significant difference, we can justify this finding because business models tend to discount products that aren't being sold much. Lower rated products don't sell as well as highly rated products, so it makes sense for brands to discount lower rated products. However, another strategy involves discounting hot products to boost its sales even more. With both these strategies and the lack of statistically significant evidence, we fail to conclude a difference in rating based on discounts.
#
# For future analysis, I think it would be really interesting to see the relationship between dollar amount discounted and the ratings.

# %% [markdown]
# ## Decision Making

# %%
hi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-55ca6286e3e4> in <module>
# ----> 1 hi
#
# NameError: name 'hi' is not defined
